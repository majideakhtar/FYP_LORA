# %% [markdown]
# # HEADER FILES

# %%
import pandas as pd
import numpy as np
import csv
import json
import psycopg2

# %% [markdown]
# # Read the CSV File

# %%
data = pd.read_csv('routes.csv')
li=[]
max=0
loc=0
for i in range(len(data)):
    k = data['route_no'][i]
    j = data['map_json_content'][i]
    js = json.dumps(j)
    jss= json.loads(js)
    str1 = str("{\""+"bus"+"\" : "+str(jss)+"}")
    count = 0
    d1=json.loads(str1)
#     print(len(d1['bus']))
    for bus in d1['bus']:
#         print(bus['busstop'])
#         print(count)
        count = count+1
#     print("---------------------")
    if count > max :
        max = count
        print("MAX=",max)
        loc=i
        
        
print(max)
print(loc)
#     print(type(d1['bus']))
    
# with open('data.json', 'w') as outfile:  
#     json.dump(li, outfile)
# Out:
# MAX= 30
# MAX= 32
# MAX= 33
# MAX= 42
# MAX= 54
# MAX= 55
# MAX= 56
# MAX= 66
# MAX= 70
# MAX= 72
# MAX= 110
# MAX= 111
# MAX= 158
# 158
# 1821

# %% [markdown]
# # DATABASE REQUESTS

# %% [markdown]
# # Creating the Table Route

# %%
for i in range(159):
    print("BSN_"+str(i)+" VARCHAR(4000),")
    print("BSL_"+str(i)+" VARCHAR(4000),")
# Out:
# BSN_0 VARCHAR(4000),
# BSL_0 VARCHAR(4000),
# BSN_1 VARCHAR(4000),
# BSL_1 VARCHAR(4000),
# BSN_2 VARCHAR(4000),
# BSL_2 VARCHAR(4000),
# BSN_3 VARCHAR(4000),
# BSL_3 VARCHAR(4000),
# BSN_4 VARCHAR(4000),
# BSL_4 VARCHAR(4000),
# BSN_5 VARCHAR(4000),
# BSL_5 VARCHAR(4000),
# BSN_6 VARCHAR(4000),
# BSL_6 VARCHAR(4000),
# BSN_7 VARCHAR(4000),
# BSL_7 VARCHAR(4000),
# BSN_8 VARCHAR(4000),
# BSL_8 VARCHAR(4000),
# BSN_9 VARCHAR(4000),
# BSL_9 VARCHAR(4000),
# BSN_10 VARCHAR(4000),
# BSL_10 VARCHAR(4000),
# BSN_11 VARCHAR(4000),
# BSL_11 VARCHAR(4000),
# BSN_12 VARCHAR(4000),
# BSL_12 VARCHAR(4000),
# BSN_13 VARCHAR(4000),
# BSL_13 VARCHAR(4000),
# BSN_14 VARCHAR(4000),
# BSL_14 VARCHAR(4000),
# BSN_15 VARCHAR(4000),
# BSL_15 VARCHAR(4000),
# BSN_16 VARCHAR(4000),
# BSL_16 VARCHAR(4000),
# BSN_17 VARCHAR(4000),
# BSL_17 VARCHAR(4000),
# BSN_18 VARCHAR(4000),
# BSL_18 VARCHAR(4000),
# BSN_19 VARCHAR(4000),
# BSL_19 VARCHAR(4000),
# BSN_20 VARCHAR(4000),
# BSL_20 VARCHAR(4000),
# BSN_21 VARCHAR(4000),
# BSL_21 VARCHAR(4000),
# BSN_22 VARCHAR(4000),
# BSL_22 VARCHAR(4000),
# BSN_23 VARCHAR(4000),
# BSL_23 VARCHAR(4000),
# BSN_24 VARCHAR(4000),
# BSL_24 VARCHAR(4000),
# BSN_25 VARCHAR(4000),
# BSL_25 VARCHAR(4000),
# BSN_26 VARCHAR(4000),
# BSL_26 VARCHAR(4000),
# BSN_27 VARCHAR(4000),
# BSL_27 VARCHAR(4000),
# BSN_28 VARCHAR(4000),
# BSL_28 VARCHAR(4000),
# BSN_29 VARCHAR(4000),
# BSL_29 VARCHAR(4000),
# BSN_30 VARCHAR(4000),
# BSL_30 VARCHAR(4000),
# BSN_31 VARCHAR(4000),
# BSL_31 VARCHAR(4000),
# BSN_32 VARCHAR(4000),
# BSL_32 VARCHAR(4000),
# BSN_33 VARCHAR(4000),
# BSL_33 VARCHAR(4000),
# BSN_34 VARCHAR(4000),
# BSL_34 VARCHAR(4000),
# BSN_35 VARCHAR(4000),
# BSL_35 VARCHAR(4000),
# BSN_36 VARCHAR(4000),
# BSL_36 VARCHAR(4000),
# BSN_37 VARCHAR(4000),
# BSL_37 VARCHAR(4000),
# BSN_38 VARCHAR(4000),
# BSL_38 VARCHAR(4000),
# BSN_39 VARCHAR(4000),
# BSL_39 VARCHAR(4000),
# BSN_40 VARCHAR(4000),
# BSL_40 VARCHAR(4000),
# BSN_41 VARCHAR(4000),
# BSL_41 VARCHAR(4000),
# BSN_42 VARCHAR(4000),
# BSL_42 VARCHAR(4000),
# BSN_43 VARCHAR(4000),
# BSL_43 VARCHAR(4000),
# BSN_44 VARCHAR(4000),
# BSL_44 VARCHAR(4000),
# BSN_45 VARCHAR(4000),
# BSL_45 VARCHAR(4000),
# BSN_46 VARCHAR(4000),
# BSL_46 VARCHAR(4000),
# BSN_47 VARCHAR(4000),
# BSL_47 VARCHAR(4000),
# BSN_48 VARCHAR(4000),
# BSL_48 VARCHAR(4000),
# BSN_49 VARCHAR(4000),
# BSL_49 VARCHAR(4000),
# BSN_50 VARCHAR(4000),
# BSL_50 VARCHAR(4000),
# BSN_51 VARCHAR(4000),
# BSL_51 VARCHAR(4000),
# BSN_52 VARCHAR(4000),
# BSL_52 VARCHAR(4000),
# BSN_53 VARCHAR(4000),
# BSL_53 VARCHAR(4000),
# BSN_54 VARCHAR(4000),
# BSL_54 VARCHAR(4000),
# BSN_55 VARCHAR(4000),
# BSL_55 VARCHAR(4000),
# BSN_56 VARCHAR(4000),
# BSL_56 VARCHAR(4000),
# BSN_57 VARCHAR(4000),
# BSL_57 VARCHAR(4000),
# BSN_58 VARCHAR(4000),
# BSL_58 VARCHAR(4000),
# BSN_59 VARCHAR(4000),
# BSL_59 VARCHAR(4000),
# BSN_60 VARCHAR(4000),
# BSL_60 VARCHAR(4000),
# BSN_61 VARCHAR(4000),
# BSL_61 VARCHAR(4000),
# BSN_62 VARCHAR(4000),
# BSL_62 VARCHAR(4000),
# BSN_63 VARCHAR(4000),
# BSL_63 VARCHAR(4000),
# BSN_64 VARCHAR(4000),
# BSL_64 VARCHAR(4000),
# BSN_65 VARCHAR(4000),
# BSL_65 VARCHAR(4000),
# BSN_66 VARCHAR(4000),
# BSL_66 VARCHAR(4000),
# BSN_67 VARCHAR(4000),
# BSL_67 VARCHAR(4000),
# BSN_68 VARCHAR(4000),
# BSL_68 VARCHAR(4000),
# BSN_69 VARCHAR(4000),
# BSL_69 VARCHAR(4000),
# BSN_70 VARCHAR(4000),
# BSL_70 VARCHAR(4000),
# BSN_71 VARCHAR(4000),
# BSL_71 VARCHAR(4000),
# BSN_72 VARCHAR(4000),
# BSL_72 VARCHAR(4000),
# BSN_73 VARCHAR(4000),
# BSL_73 VARCHAR(4000),
# BSN_74 VARCHAR(4000),
# BSL_74 VARCHAR(4000),
# BSN_75 VARCHAR(4000),
# BSL_75 VARCHAR(4000),
# BSN_76 VARCHAR(4000),
# BSL_76 VARCHAR(4000),
# BSN_77 VARCHAR(4000),
# BSL_77 VARCHAR(4000),
# BSN_78 VARCHAR(4000),
# BSL_78 VARCHAR(4000),
# BSN_79 VARCHAR(4000),
# BSL_79 VARCHAR(4000),
# BSN_80 VARCHAR(4000),
# BSL_80 VARCHAR(4000),
# BSN_81 VARCHAR(4000),
# BSL_81 VARCHAR(4000),
# BSN_82 VARCHAR(4000),
# BSL_82 VARCHAR(4000),
# BSN_83 VARCHAR(4000),
# BSL_83 VARCHAR(4000),
# BSN_84 VARCHAR(4000),
# BSL_84 VARCHAR(4000),
# BSN_85 VARCHAR(4000),
# BSL_85 VARCHAR(4000),
# BSN_86 VARCHAR(4000),
# BSL_86 VARCHAR(4000),
# BSN_87 VARCHAR(4000),
# BSL_87 VARCHAR(4000),
# BSN_88 VARCHAR(4000),
# BSL_88 VARCHAR(4000),
# BSN_89 VARCHAR(4000),
# BSL_89 VARCHAR(4000),
# BSN_90 VARCHAR(4000),
# BSL_90 VARCHAR(4000),
# BSN_91 VARCHAR(4000),
# BSL_91 VARCHAR(4000),
# BSN_92 VARCHAR(4000),
# BSL_92 VARCHAR(4000),
# BSN_93 VARCHAR(4000),
# BSL_93 VARCHAR(4000),
# BSN_94 VARCHAR(4000),
# BSL_94 VARCHAR(4000),
# BSN_95 VARCHAR(4000),
# BSL_95 VARCHAR(4000),
# BSN_96 VARCHAR(4000),
# BSL_96 VARCHAR(4000),
# BSN_97 VARCHAR(4000),
# BSL_97 VARCHAR(4000),
# BSN_98 VARCHAR(4000),
# BSL_98 VARCHAR(4000),
# BSN_99 VARCHAR(4000),
# BSL_99 VARCHAR(4000),
# BSN_100 VARCHAR(4000),
# BSL_100 VARCHAR(4000),
# BSN_101 VARCHAR(4000),
# BSL_101 VARCHAR(4000),
# BSN_102 VARCHAR(4000),
# BSL_102 VARCHAR(4000),
# BSN_103 VARCHAR(4000),
# BSL_103 VARCHAR(4000),
# BSN_104 VARCHAR(4000),
# BSL_104 VARCHAR(4000),
# BSN_105 VARCHAR(4000),
# BSL_105 VARCHAR(4000),
# BSN_106 VARCHAR(4000),
# BSL_106 VARCHAR(4000),
# BSN_107 VARCHAR(4000),
# BSL_107 VARCHAR(4000),
# BSN_108 VARCHAR(4000),
# BSL_108 VARCHAR(4000),
# BSN_109 VARCHAR(4000),
# BSL_109 VARCHAR(4000),
# BSN_110 VARCHAR(4000),
# BSL_110 VARCHAR(4000),
# BSN_111 VARCHAR(4000),
# BSL_111 VARCHAR(4000),
# BSN_112 VARCHAR(4000),
# BSL_112 VARCHAR(4000),
# BSN_113 VARCHAR(4000),
# BSL_113 VARCHAR(4000),
# BSN_114 VARCHAR(4000),
# BSL_114 VARCHAR(4000),
# BSN_115 VARCHAR(4000),
# BSL_115 VARCHAR(4000),
# BSN_116 VARCHAR(4000),
# BSL_116 VARCHAR(4000),
# BSN_117 VARCHAR(4000),
# BSL_117 VARCHAR(4000),
# BSN_118 VARCHAR(4000),
# BSL_118 VARCHAR(4000),
# BSN_119 VARCHAR(4000),
# BSL_119 VARCHAR(4000),
# BSN_120 VARCHAR(4000),
# BSL_120 VARCHAR(4000),
# BSN_121 VARCHAR(4000),
# BSL_121 VARCHAR(4000),
# BSN_122 VARCHAR(4000),
# BSL_122 VARCHAR(4000),
# BSN_123 VARCHAR(4000),
# BSL_123 VARCHAR(4000),
# BSN_124 VARCHAR(4000),
# BSL_124 VARCHAR(4000),
# BSN_125 VARCHAR(4000),
# BSL_125 VARCHAR(4000),
# BSN_126 VARCHAR(4000),
# BSL_126 VARCHAR(4000),
# BSN_127 VARCHAR(4000),
# BSL_127 VARCHAR(4000),
# BSN_128 VARCHAR(4000),
# BSL_128 VARCHAR(4000),
# BSN_129 VARCHAR(4000),
# BSL_129 VARCHAR(4000),
# BSN_130 VARCHAR(4000),
# BSL_130 VARCHAR(4000),
# BSN_131 VARCHAR(4000),
# BSL_131 VARCHAR(4000),
# BSN_132 VARCHAR(4000),
# BSL_132 VARCHAR(4000),
# BSN_133 VARCHAR(4000),
# BSL_133 VARCHAR(4000),
# BSN_134 VARCHAR(4000),
# BSL_134 VARCHAR(4000),
# BSN_135 VARCHAR(4000),
# BSL_135 VARCHAR(4000),
# BSN_136 VARCHAR(4000),
# BSL_136 VARCHAR(4000),
# BSN_137 VARCHAR(4000),
# BSL_137 VARCHAR(4000),
# BSN_138 VARCHAR(4000),
# BSL_138 VARCHAR(4000),
# BSN_139 VARCHAR(4000),
# BSL_139 VARCHAR(4000),
# BSN_140 VARCHAR(4000),
# BSL_140 VARCHAR(4000),
# BSN_141 VARCHAR(4000),
# BSL_141 VARCHAR(4000),
# BSN_142 VARCHAR(4000),
# BSL_142 VARCHAR(4000),
# BSN_143 VARCHAR(4000),
# BSL_143 VARCHAR(4000),
# BSN_144 VARCHAR(4000),
# BSL_144 VARCHAR(4000),
# BSN_145 VARCHAR(4000),
# BSL_145 VARCHAR(4000),
# BSN_146 VARCHAR(4000),
# BSL_146 VARCHAR(4000),
# BSN_147 VARCHAR(4000),
# BSL_147 VARCHAR(4000),
# BSN_148 VARCHAR(4000),
# BSL_148 VARCHAR(4000),
# BSN_149 VARCHAR(4000),
# BSL_149 VARCHAR(4000),
# BSN_150 VARCHAR(4000),
# BSL_150 VARCHAR(4000),
# BSN_151 VARCHAR(4000),
# BSL_151 VARCHAR(4000),
# BSN_152 VARCHAR(4000),
# BSL_152 VARCHAR(4000),
# BSN_153 VARCHAR(4000),
# BSL_153 VARCHAR(4000),
# BSN_154 VARCHAR(4000),
# BSL_154 VARCHAR(4000),
# BSN_155 VARCHAR(4000),
# BSL_155 VARCHAR(4000),
# BSN_156 VARCHAR(4000),
# BSL_156 VARCHAR(4000),
# BSN_157 VARCHAR(4000),
# BSL_157 VARCHAR(4000),
# BSN_158 VARCHAR(4000),
# BSL_158 VARCHAR(4000),

# %%
import psycopg2

conn = psycopg2.connect(database="lora_db", user = "postgres", password = "postgres", host = "127.0.0.1", port = "5432")
# conn = psycopg2.connect("dbname=lora_db user=postgres password=postgres")
# conn = psycopg2.connect(host="localhost",database="lora_db", user="postgres", password="postgres")
print(conn)
cur = conn.cursor()

# cur.execute('''
# CREATE TABLE routes
# (route_no VARCHAR(30),
# origin VARCHAR(4000),
# destination VARCHAR(4000),
# BSN_1 VARCHAR(4000),
# BSL_1 VARCHAR(4000),
# BSN_2 VARCHAR(4000),
# BSL_2 VARCHAR(4000),
# BSN_3 VARCHAR(4000),
# BSL_3 VARCHAR(4000),
# BSN_4 VARCHAR(4000),
# BSL_4 VARCHAR(4000),
# BSN_5 VARCHAR(4000),
# BSL_5 VARCHAR(4000),
# BSN_6 VARCHAR(4000),
# BSL_6 VARCHAR(4000),
# BSN_7 VARCHAR(4000),
# BSL_7 VARCHAR(4000),
# BSN_8 VARCHAR(4000),
# BSL_8 VARCHAR(4000),
# BSN_9 VARCHAR(4000),
# BSL_9 VARCHAR(4000),
# BSN_10 VARCHAR(4000),
# BSL_10 VARCHAR(4000),
# BSN_11 VARCHAR(4000),
# BSL_11 VARCHAR(4000),
# BSN_12 VARCHAR(4000),
# BSL_12 VARCHAR(4000),
# BSN_13 VARCHAR(4000),
# BSL_13 VARCHAR(4000),
# BSN_14 VARCHAR(4000),
# BSL_14 VARCHAR(4000),
# BSN_15 VARCHAR(4000),
# BSL_15 VARCHAR(4000),
# BSN_16 VARCHAR(4000),
# BSL_16 VARCHAR(4000),
# BSN_17 VARCHAR(4000),
# BSL_17 VARCHAR(4000),
# BSN_18 VARCHAR(4000),
# BSL_18 VARCHAR(4000),
# BSN_19 VARCHAR(4000),
# BSL_19 VARCHAR(4000),
# BSN_20 VARCHAR(4000),
# BSL_20 VARCHAR(4000),
# BSN_21 VARCHAR(4000),
# BSL_21 VARCHAR(4000),
# BSN_22 VARCHAR(4000),
# BSL_22 VARCHAR(4000),
# BSN_23 VARCHAR(4000),
# BSL_23 VARCHAR(4000),
# BSN_24 VARCHAR(4000),
# BSL_24 VARCHAR(4000),
# BSN_25 VARCHAR(4000),
# BSL_25 VARCHAR(4000),
# BSN_26 VARCHAR(4000),
# BSL_26 VARCHAR(4000),
# BSN_27 VARCHAR(4000),
# BSL_27 VARCHAR(4000),
# BSN_28 VARCHAR(4000),
# BSL_28 VARCHAR(4000),
# BSN_29 VARCHAR(4000),
# BSL_29 VARCHAR(4000),
# BSN_30 VARCHAR(4000),
# BSL_30 VARCHAR(4000),
# BSN_31 VARCHAR(4000),
# BSL_31 VARCHAR(4000),
# BSN_32 VARCHAR(4000),
# BSL_32 VARCHAR(4000),
# BSN_33 VARCHAR(4000),
# BSL_33 VARCHAR(4000),
# BSN_34 VARCHAR(4000),
# BSL_34 VARCHAR(4000),
# BSN_35 VARCHAR(4000),
# BSL_35 VARCHAR(4000),
# BSN_36 VARCHAR(4000),
# BSL_36 VARCHAR(4000),
# BSN_37 VARCHAR(4000),
# BSL_37 VARCHAR(4000),
# BSN_38 VARCHAR(4000),
# BSL_38 VARCHAR(4000),
# BSN_39 VARCHAR(4000),
# BSL_39 VARCHAR(4000),
# BSN_40 VARCHAR(4000),
# BSL_40 VARCHAR(4000),
# BSN_41 VARCHAR(4000),
# BSL_41 VARCHAR(4000),
# BSN_42 VARCHAR(4000),
# BSL_42 VARCHAR(4000),
# BSN_43 VARCHAR(4000),
# BSL_43 VARCHAR(4000),
# BSN_44 VARCHAR(4000),
# BSL_44 VARCHAR(4000),
# BSN_45 VARCHAR(4000),
# BSL_45 VARCHAR(4000),
# BSN_46 VARCHAR(4000),
# BSL_46 VARCHAR(4000),
# BSN_47 VARCHAR(4000),
# BSL_47 VARCHAR(4000),
# BSN_48 VARCHAR(4000),
# BSL_48 VARCHAR(4000),
# BSN_49 VARCHAR(4000),
# BSL_49 VARCHAR(4000),
# BSN_50 VARCHAR(4000),
# BSL_50 VARCHAR(4000),
# BSN_51 VARCHAR(4000),
# BSL_51 VARCHAR(4000),
# BSN_52 VARCHAR(4000),
# BSL_52 VARCHAR(4000),
# BSN_53 VARCHAR(4000),
# BSL_53 VARCHAR(4000),
# BSN_54 VARCHAR(4000),
# BSL_54 VARCHAR(4000),
# BSN_55 VARCHAR(4000),
# BSL_55 VARCHAR(4000),
# BSN_56 VARCHAR(4000),
# BSL_56 VARCHAR(4000),
# BSN_57 VARCHAR(4000),
# BSL_57 VARCHAR(4000),
# BSN_58 VARCHAR(4000),
# BSL_58 VARCHAR(4000),
# BSN_59 VARCHAR(4000),
# BSL_59 VARCHAR(4000),
# BSN_60 VARCHAR(4000),
# BSL_60 VARCHAR(4000),
# BSN_61 VARCHAR(4000),
# BSL_61 VARCHAR(4000),
# BSN_62 VARCHAR(4000),
# BSL_62 VARCHAR(4000),
# BSN_63 VARCHAR(4000),
# BSL_63 VARCHAR(4000),
# BSN_64 VARCHAR(4000),
# BSL_64 VARCHAR(4000),
# BSN_65 VARCHAR(4000),
# BSL_65 VARCHAR(4000),
# BSN_66 VARCHAR(4000),
# BSL_66 VARCHAR(4000),
# BSN_67 VARCHAR(4000),
# BSL_67 VARCHAR(4000),
# BSN_68 VARCHAR(4000),
# BSL_68 VARCHAR(4000),
# BSN_69 VARCHAR(4000),
# BSL_69 VARCHAR(4000),
# BSN_70 VARCHAR(4000),
# BSL_70 VARCHAR(4000),
# BSN_71 VARCHAR(4000),
# BSL_71 VARCHAR(4000),
# BSN_72 VARCHAR(4000),
# BSL_72 VARCHAR(4000),
# BSN_73 VARCHAR(4000),
# BSL_73 VARCHAR(4000),
# BSN_74 VARCHAR(4000),
# BSL_74 VARCHAR(4000),
# BSN_75 VARCHAR(4000),
# BSL_75 VARCHAR(4000),
# BSN_76 VARCHAR(4000),
# BSL_76 VARCHAR(4000),
# BSN_77 VARCHAR(4000),
# BSL_77 VARCHAR(4000),
# BSN_78 VARCHAR(4000),
# BSL_78 VARCHAR(4000),
# BSN_79 VARCHAR(4000),
# BSL_79 VARCHAR(4000),
# BSN_80 VARCHAR(4000),
# BSL_80 VARCHAR(4000),
# BSN_81 VARCHAR(4000),
# BSL_81 VARCHAR(4000),
# BSN_82 VARCHAR(4000),
# BSL_82 VARCHAR(4000),
# BSN_83 VARCHAR(4000),
# BSL_83 VARCHAR(4000),
# BSN_84 VARCHAR(4000),
# BSL_84 VARCHAR(4000),
# BSN_85 VARCHAR(4000),
# BSL_85 VARCHAR(4000),
# BSN_86 VARCHAR(4000),
# BSL_86 VARCHAR(4000),
# BSN_87 VARCHAR(4000),
# BSL_87 VARCHAR(4000),
# BSN_88 VARCHAR(4000),
# BSL_88 VARCHAR(4000),
# BSN_89 VARCHAR(4000),
# BSL_89 VARCHAR(4000),
# BSN_90 VARCHAR(4000),
# BSL_90 VARCHAR(4000),
# BSN_91 VARCHAR(4000),
# BSL_91 VARCHAR(4000),
# BSN_92 VARCHAR(4000),
# BSL_92 VARCHAR(4000),
# BSN_93 VARCHAR(4000),
# BSL_93 VARCHAR(4000),
# BSN_94 VARCHAR(4000),
# BSL_94 VARCHAR(4000),
# BSN_95 VARCHAR(4000),
# BSL_95 VARCHAR(4000),
# BSN_96 VARCHAR(4000),
# BSL_96 VARCHAR(4000),
# BSN_97 VARCHAR(4000),
# BSL_97 VARCHAR(4000),
# BSN_98 VARCHAR(4000),
# BSL_98 VARCHAR(4000),
# BSN_99 VARCHAR(4000),
# BSL_99 VARCHAR(4000),
# BSN_100 VARCHAR(4000),
# BSL_100 VARCHAR(4000),
# BSN_101 VARCHAR(4000),
# BSL_101 VARCHAR(4000),
# BSN_102 VARCHAR(4000),
# BSL_102 VARCHAR(4000),
# BSN_103 VARCHAR(4000),
# BSL_103 VARCHAR(4000),
# BSN_104 VARCHAR(4000),
# BSL_104 VARCHAR(4000),
# BSN_105 VARCHAR(4000),
# BSL_105 VARCHAR(4000),
# BSN_106 VARCHAR(4000),
# BSL_106 VARCHAR(4000),
# BSN_107 VARCHAR(4000),
# BSL_107 VARCHAR(4000),
# BSN_108 VARCHAR(4000),
# BSL_108 VARCHAR(4000),
# BSN_109 VARCHAR(4000),
# BSL_109 VARCHAR(4000),
# BSN_110 VARCHAR(4000),
# BSL_110 VARCHAR(4000),
# BSN_111 VARCHAR(4000),
# BSL_111 VARCHAR(4000),
# BSN_112 VARCHAR(4000),
# BSL_112 VARCHAR(4000),
# BSN_113 VARCHAR(4000),
# BSL_113 VARCHAR(4000),
# BSN_114 VARCHAR(4000),
# BSL_114 VARCHAR(4000),
# BSN_115 VARCHAR(4000),
# BSL_115 VARCHAR(4000),
# BSN_116 VARCHAR(4000),
# BSL_116 VARCHAR(4000),
# BSN_117 VARCHAR(4000),
# BSL_117 VARCHAR(4000),
# BSN_118 VARCHAR(4000),
# BSL_118 VARCHAR(4000),
# BSN_119 VARCHAR(4000),
# BSL_119 VARCHAR(4000),
# BSN_120 VARCHAR(4000),
# BSL_120 VARCHAR(4000),
# BSN_121 VARCHAR(4000),
# BSL_121 VARCHAR(4000),
# BSN_122 VARCHAR(4000),
# BSL_122 VARCHAR(4000),
# BSN_123 VARCHAR(4000),
# BSL_123 VARCHAR(4000),
# BSN_124 VARCHAR(4000),
# BSL_124 VARCHAR(4000),
# BSN_125 VARCHAR(4000),
# BSL_125 VARCHAR(4000),
# BSN_126 VARCHAR(4000),
# BSL_126 VARCHAR(4000),
# BSN_127 VARCHAR(4000),
# BSL_127 VARCHAR(4000),
# BSN_128 VARCHAR(4000),
# BSL_128 VARCHAR(4000),
# BSN_129 VARCHAR(4000),
# BSL_129 VARCHAR(4000),
# BSN_130 VARCHAR(4000),
# BSL_130 VARCHAR(4000),
# BSN_131 VARCHAR(4000),
# BSL_131 VARCHAR(4000),
# BSN_132 VARCHAR(4000),
# BSL_132 VARCHAR(4000),
# BSN_133 VARCHAR(4000),
# BSL_133 VARCHAR(4000),
# BSN_134 VARCHAR(4000),
# BSL_134 VARCHAR(4000),
# BSN_135 VARCHAR(4000),
# BSL_135 VARCHAR(4000),
# BSN_136 VARCHAR(4000),
# BSL_136 VARCHAR(4000),
# BSN_137 VARCHAR(4000),
# BSL_137 VARCHAR(4000),
# BSN_138 VARCHAR(4000),
# BSL_138 VARCHAR(4000),
# BSN_139 VARCHAR(4000),
# BSL_139 VARCHAR(4000),
# BSN_140 VARCHAR(4000),
# BSL_140 VARCHAR(4000),
# BSN_141 VARCHAR(4000),
# BSL_141 VARCHAR(4000),
# BSN_142 VARCHAR(4000),
# BSL_142 VARCHAR(4000),
# BSN_143 VARCHAR(4000),
# BSL_143 VARCHAR(4000),
# BSN_144 VARCHAR(4000),
# BSL_144 VARCHAR(4000),
# BSN_145 VARCHAR(4000),
# BSL_145 VARCHAR(4000),
# BSN_146 VARCHAR(4000),
# BSL_146 VARCHAR(4000),
# BSN_147 VARCHAR(4000),
# BSL_147 VARCHAR(4000),
# BSN_148 VARCHAR(4000),
# BSL_148 VARCHAR(4000),
# BSN_149 VARCHAR(4000),
# BSL_149 VARCHAR(4000),
# BSN_150 VARCHAR(4000),
# BSL_150 VARCHAR(4000),
# BSN_151 VARCHAR(4000),
# BSL_151 VARCHAR(4000),
# BSN_152 VARCHAR(4000),
# BSL_152 VARCHAR(4000),
# BSN_153 VARCHAR(4000),
# BSL_153 VARCHAR(4000),
# BSN_154 VARCHAR(4000),
# BSL_154 VARCHAR(4000),
# BSN_155 VARCHAR(4000),
# BSL_155 VARCHAR(4000),
# BSN_156 VARCHAR(4000),
# BSL_156 VARCHAR(4000),
# BSN_157 VARCHAR(4000),
# BSL_157 VARCHAR(4000),
# BSN_158 VARCHAR(4000),
# BSL_158 VARCHAR(4000)
# )
# ''')

# conn.commit()


cur.execute("SELECT * FROM routes")

myresult = cur.fetchall()

for x in myresult:
  print(x)

conn.close()
# Out:
# <connection object at 0x0000026C11111BA0; dsn: 'user=postgres password=xxx dbname=lora_db host=127.0.0.1 port=5432', closed: 0>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Passing Data to Route

# %%
conn = psycopg2.connect(database="lora_db", user = "postgres", password = "postgres", host = "127.0.0.1", port = "5432")
print(conn)
cur = conn.cursor()

data = pd.read_csv('routes.csv')

for i in range(len(data)):
    route_no = str(data['route_no'][i])
    origin = str(data['origin'][i])
    destination = str(data['destination'][i])
    
    sql = "INSERT INTO routes (route_no, origin, destination, BSN_1, BSL_1, BSN_2, BSL_2, BSN_3, BSL_3, BSN_4, BSL_4, BSN_5, BSL_5, BSN_6, BSL_6, BSN_7, BSL_7, BSN_8, BSL_8, BSN_9, BSL_9, BSN_10, BSL_10, BSN_11, BSL_11, BSN_12, BSL_12, BSN_13, BSL_13, BSN_14, BSL_14, BSN_15, BSL_15, BSN_16, BSL_16, BSN_17, BSL_17, BSN_18, BSL_18, BSN_19, BSL_19, BSN_20, BSL_20, BSN_21, BSL_21, BSN_22, BSL_22, BSN_23, BSL_23, BSN_24, BSL_24, BSN_25, BSL_25, BSN_26, BSL_26, BSN_27, BSL_27, BSN_28, BSL_28, BSN_29, BSL_29, BSN_30, BSL_30, BSN_31, BSL_31, BSN_32, BSL_32, BSN_33, BSL_33, BSN_34, BSL_34, BSN_35, BSL_35, BSN_36, BSL_36, BSN_37, BSL_37, BSN_38, BSL_38, BSN_39, BSL_39, BSN_40, BSL_40, BSN_41, BSL_41, BSN_42, BSL_42, BSN_43, BSL_43, BSN_44, BSL_44, BSN_45, BSL_45, BSN_46, BSL_46, BSN_47, BSL_47, BSN_48, BSL_48, BSN_49, BSL_49, BSN_50, BSL_50, BSN_51, BSL_51, BSN_52, BSL_52, BSN_53, BSL_53, BSN_54, BSL_54, BSN_55, BSL_55, BSN_56, BSL_56, BSN_57, BSL_57, BSN_58, BSL_58, BSN_59, BSL_59, BSN_60, BSL_60, BSN_61, BSL_61, BSN_62, BSL_62, BSN_63, BSL_63, BSN_64, BSL_64, BSN_65, BSL_65, BSN_66, BSL_66, BSN_67, BSL_67, BSN_68, BSL_68, BSN_69, BSL_69, BSN_70, BSL_70, BSN_71, BSL_71, BSN_72, BSL_72, BSN_73, BSL_73, BSN_74, BSL_74, BSN_75, BSL_75, BSN_76, BSL_76, BSN_77, BSL_77, BSN_78, BSL_78, BSN_79, BSL_79, BSN_80, BSL_80, BSN_81, BSL_81, BSN_82, BSL_82, BSN_83, BSL_83, BSN_84, BSL_84, BSN_85, BSL_85, BSN_86, BSL_86, BSN_87, BSL_87, BSN_88, BSL_88, BSN_89, BSL_89, BSN_90, BSL_90, BSN_91, BSL_91, BSN_92, BSL_92, BSN_93, BSL_93, BSN_94, BSL_94, BSN_95, BSL_95, BSN_96, BSL_96, BSN_97, BSL_97, BSN_98, BSL_98, BSN_99, BSL_99, BSN_100, BSL_100, BSN_101, BSL_101, BSN_102, BSL_102, BSN_103, BSL_103, BSN_104, BSL_104, BSN_105, BSL_105, BSN_106, BSL_106, BSN_107, BSL_107, BSN_108, BSL_108, BSN_109, BSL_109, BSN_110, BSL_110, BSN_111, BSL_111, BSN_112, BSL_112, BSN_113, BSL_113, BSN_114, BSL_114, BSN_115, BSL_115, BSN_116, BSL_116, BSN_117, BSL_117, BSN_118, BSL_118, BSN_119, BSL_119, BSN_120, BSL_120, BSN_121, BSL_121, BSN_122, BSL_122, BSN_123, BSL_123, BSN_124, BSL_124, BSN_125, BSL_125, BSN_126, BSL_126, BSN_127, BSL_127, BSN_128, BSL_128, BSN_129, BSL_129, BSN_130, BSL_130, BSN_131, BSL_131, BSN_132, BSL_132, BSN_133, BSL_133, BSN_134, BSL_134, BSN_135, BSL_135, BSN_136, BSL_136, BSN_137, BSL_137, BSN_138, BSL_138, BSN_139, BSL_139, BSN_140, BSL_140, BSN_141, BSL_141, BSN_142, BSL_142, BSN_143, BSL_143, BSN_144, BSL_144, BSN_145, BSL_145, BSN_146, BSL_146, BSN_147, BSL_147, BSN_148, BSL_148, BSN_149, BSL_149, BSN_150, BSL_150, BSN_151, BSL_151, BSN_152, BSL_152, BSN_153, BSL_153, BSN_154, BSL_154,BSN_155, BSL_155, BSN_156, BSL_156, BSN_157, BSL_157,BSN_158, BSL_158) VALUES  (%s, %s, %s, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL);"
    val = (route_no, origin, destination)
    cur.execute(sql, val)
    conn.commit()
    
    #Converting to recognised JSON
    j = data['map_json_content'][i]
    js = json.dumps(j)
    jss= json.loads(js)
    str1 = str("{\""+"bus"+"\" : "+str(jss)+"}")
    d1=json.loads(str1)
    
    k = 1
    for bus in d1['bus']:
        busstop = str(bus['busstop'])
        latlons = str(bus['latlons'])

        sql = str("UPDATE routes SET BSN_"+str(k)+" = %s , BSL_"+str(k)+" = %s  WHERE route_no = %s")
        val = (busstop, latlons, route_no)
        cur.execute(sql, val)
        conn.commit()
        
        k=k+1
# Out:
# <connection object at 0x0000026C0F461258; dsn: 'user=postgres password=xxx dbname=lora_db host=127.0.0.1 port=5432', closed: 0>

# %% [markdown]
# # Creating the table lora_gps_data

# %%
for i in range(159):
    print("BST_"+str(i)+" TIME,")
# Out:
# BST_0 TIME,
# BST_1 TIME,
# BST_2 TIME,
# BST_3 TIME,
# BST_4 TIME,
# BST_5 TIME,
# BST_6 TIME,
# BST_7 TIME,
# BST_8 TIME,
# BST_9 TIME,
# BST_10 TIME,
# BST_11 TIME,
# BST_12 TIME,
# BST_13 TIME,
# BST_14 TIME,
# BST_15 TIME,
# BST_16 TIME,
# BST_17 TIME,
# BST_18 TIME,
# BST_19 TIME,
# BST_20 TIME,
# BST_21 TIME,
# BST_22 TIME,
# BST_23 TIME,
# BST_24 TIME,
# BST_25 TIME,
# BST_26 TIME,
# BST_27 TIME,
# BST_28 TIME,
# BST_29 TIME,
# BST_30 TIME,
# BST_31 TIME,
# BST_32 TIME,
# BST_33 TIME,
# BST_34 TIME,
# BST_35 TIME,
# BST_36 TIME,
# BST_37 TIME,
# BST_38 TIME,
# BST_39 TIME,
# BST_40 TIME,
# BST_41 TIME,
# BST_42 TIME,
# BST_43 TIME,
# BST_44 TIME,
# BST_45 TIME,
# BST_46 TIME,
# BST_47 TIME,
# BST_48 TIME,
# BST_49 TIME,
# BST_50 TIME,
# BST_51 TIME,
# BST_52 TIME,
# BST_53 TIME,
# BST_54 TIME,
# BST_55 TIME,
# BST_56 TIME,
# BST_57 TIME,
# BST_58 TIME,
# BST_59 TIME,
# BST_60 TIME,
# BST_61 TIME,
# BST_62 TIME,
# BST_63 TIME,
# BST_64 TIME,
# BST_65 TIME,
# BST_66 TIME,
# BST_67 TIME,
# BST_68 TIME,
# BST_69 TIME,
# BST_70 TIME,
# BST_71 TIME,
# BST_72 TIME,
# BST_73 TIME,
# BST_74 TIME,
# BST_75 TIME,
# BST_76 TIME,
# BST_77 TIME,
# BST_78 TIME,
# BST_79 TIME,
# BST_80 TIME,
# BST_81 TIME,
# BST_82 TIME,
# BST_83 TIME,
# BST_84 TIME,
# BST_85 TIME,
# BST_86 TIME,
# BST_87 TIME,
# BST_88 TIME,
# BST_89 TIME,
# BST_90 TIME,
# BST_91 TIME,
# BST_92 TIME,
# BST_93 TIME,
# BST_94 TIME,
# BST_95 TIME,
# BST_96 TIME,
# BST_97 TIME,
# BST_98 TIME,
# BST_99 TIME,
# BST_100 TIME,
# BST_101 TIME,
# BST_102 TIME,
# BST_103 TIME,
# BST_104 TIME,
# BST_105 TIME,
# BST_106 TIME,
# BST_107 TIME,
# BST_108 TIME,
# BST_109 TIME,
# BST_110 TIME,
# BST_111 TIME,
# BST_112 TIME,
# BST_113 TIME,
# BST_114 TIME,
# BST_115 TIME,
# BST_116 TIME,
# BST_117 TIME,
# BST_118 TIME,
# BST_119 TIME,
# BST_120 TIME,
# BST_121 TIME,
# BST_122 TIME,
# BST_123 TIME,
# BST_124 TIME,
# BST_125 TIME,
# BST_126 TIME,
# BST_127 TIME,
# BST_128 TIME,
# BST_129 TIME,
# BST_130 TIME,
# BST_131 TIME,
# BST_132 TIME,
# BST_133 TIME,
# BST_134 TIME,
# BST_135 TIME,
# BST_136 TIME,
# BST_137 TIME,
# BST_138 TIME,
# BST_139 TIME,
# BST_140 TIME,
# BST_141 TIME,
# BST_142 TIME,
# BST_143 TIME,
# BST_144 TIME,
# BST_145 TIME,
# BST_146 TIME,
# BST_147 TIME,
# BST_148 TIME,
# BST_149 TIME,
# BST_150 TIME,
# BST_151 TIME,
# BST_152 TIME,
# BST_153 TIME,
# BST_154 TIME,
# BST_155 TIME,
# BST_156 TIME,
# BST_157 TIME,
# BST_158 TIME,

# %%
import psycopg2

conn = psycopg2.connect(database="lora_db", user = "postgres", password = "postgres", host = "127.0.0.1", port = "5432")
# conn = psycopg2.connect("dbname=lora_db user=postgres password=postgres")
# conn = psycopg2.connect(host="localhost",database="lora_db", user="postgres", password="postgres")
print(conn)
cur = conn.cursor()

cur.execute('''
CREATE TABLE lora_gps_data
(route_no VARCHAR(30),
time_origin TIME,
time_destination TIME,
BST_1 TIME,
BST_2 TIME,
BST_3 TIME,
BST_4 TIME,
BST_5 TIME,
BST_6 TIME,
BST_7 TIME,
BST_8 TIME,
BST_9 TIME,
BST_10 TIME,
BST_11 TIME,
BST_12 TIME,
BST_13 TIME,
BST_14 TIME,
BST_15 TIME,
BST_16 TIME,
BST_17 TIME,
BST_18 TIME,
BST_19 TIME,
BST_20 TIME,
BST_21 TIME,
BST_22 TIME,
BST_23 TIME,
BST_24 TIME,
BST_25 TIME,
BST_26 TIME,
BST_27 TIME,
BST_28 TIME,
BST_29 TIME,
BST_30 TIME,
BST_31 TIME,
BST_32 TIME,
BST_33 TIME,
BST_34 TIME,
BST_35 TIME,
BST_36 TIME,
BST_37 TIME,
BST_38 TIME,
BST_39 TIME,
BST_40 TIME,
BST_41 TIME,
BST_42 TIME,
BST_43 TIME,
BST_44 TIME,
BST_45 TIME,
BST_46 TIME,
BST_47 TIME,
BST_48 TIME,
BST_49 TIME,
BST_50 TIME,
BST_51 TIME,
BST_52 TIME,
BST_53 TIME,
BST_54 TIME,
BST_55 TIME,
BST_56 TIME,
BST_57 TIME,
BST_58 TIME,
BST_59 TIME,
BST_60 TIME,
BST_61 TIME,
BST_62 TIME,
BST_63 TIME,
BST_64 TIME,
BST_65 TIME,
BST_66 TIME,
BST_67 TIME,
BST_68 TIME,
BST_69 TIME,
BST_70 TIME,
BST_71 TIME,
BST_72 TIME,
BST_73 TIME,
BST_74 TIME,
BST_75 TIME,
BST_76 TIME,
BST_77 TIME,
BST_78 TIME,
BST_79 TIME,
BST_80 TIME,
BST_81 TIME,
BST_82 TIME,
BST_83 TIME,
BST_84 TIME,
BST_85 TIME,
BST_86 TIME,
BST_87 TIME,
BST_88 TIME,
BST_89 TIME,
BST_90 TIME,
BST_91 TIME,
BST_92 TIME,
BST_93 TIME,
BST_94 TIME,
BST_95 TIME,
BST_96 TIME,
BST_97 TIME,
BST_98 TIME,
BST_99 TIME,
BST_100 TIME,
BST_101 TIME,
BST_102 TIME,
BST_103 TIME,
BST_104 TIME,
BST_105 TIME,
BST_106 TIME,
BST_107 TIME,
BST_108 TIME,
BST_109 TIME,
BST_110 TIME,
BST_111 TIME,
BST_112 TIME,
BST_113 TIME,
BST_114 TIME,
BST_115 TIME,
BST_116 TIME,
BST_117 TIME,
BST_118 TIME,
BST_119 TIME,
BST_120 TIME,
BST_121 TIME,
BST_122 TIME,
BST_123 TIME,
BST_124 TIME,
BST_125 TIME,
BST_126 TIME,
BST_127 TIME,
BST_128 TIME,
BST_129 TIME,
BST_130 TIME,
BST_131 TIME,
BST_132 TIME,
BST_133 TIME,
BST_134 TIME,
BST_135 TIME,
BST_136 TIME,
BST_137 TIME,
BST_138 TIME,
BST_139 TIME,
BST_140 TIME,
BST_141 TIME,
BST_142 TIME,
BST_143 TIME,
BST_144 TIME,
BST_145 TIME,
BST_146 TIME,
BST_147 TIME,
BST_148 TIME,
BST_149 TIME,
BST_150 TIME,
BST_151 TIME,
BST_152 TIME,
BST_153 TIME,
BST_154 TIME,
BST_155 TIME,
BST_156 TIME,
BST_157 TIME,
BST_158 TIME)
)
''')

conn.commit()

# %%
conn = psycopg2.connect(database="lora_db", user = "postgres", password = "postgres", host = "127.0.0.1", port = "5432")
print(conn)
cur = conn.cursor()

data = pd.read_csv('routes.csv')

for i in range(len(data)):
    route_no = str(data['route_no'][i])
    origin = str(data['origin'][i])
    destination = str(data['destination'][i])
    
    sql = "INSERT INTO routes (route_no, origin, destination, BSN_1, BSL_1, BSN_2, BSL_2, BSN_3, BSL_3, BSN_4, BSL_4, BSN_5, BSL_5, BSN_6, BSL_6, BSN_7, BSL_7, BSN_8, BSL_8, BSN_9, BSL_9, BSN_10, BSL_10, BSN_11, BSL_11, BSN_12, BSL_12, BSN_13, BSL_13, BSN_14, BSL_14, BSN_15, BSL_15, BSN_16, BSL_16, BSN_17, BSL_17, BSN_18, BSL_18, BSN_19, BSL_19, BSN_20, BSL_20, BSN_21, BSL_21, BSN_22, BSL_22, BSN_23, BSL_23, BSN_24, BSL_24, BSN_25, BSL_25, BSN_26, BSL_26, BSN_27, BSL_27, BSN_28, BSL_28, BSN_29, BSL_29, BSN_30, BSL_30, BSN_31, BSL_31, BSN_32, BSL_32, BSN_33, BSL_33, BSN_34, BSL_34, BSN_35, BSL_35, BSN_36, BSL_36, BSN_37, BSL_37, BSN_38, BSL_38, BSN_39, BSL_39, BSN_40, BSL_40, BSN_41, BSL_41, BSN_42, BSL_42, BSN_43, BSL_43, BSN_44, BSL_44, BSN_45, BSL_45, BSN_46, BSL_46, BSN_47, BSL_47, BSN_48, BSL_48, BSN_49, BSL_49, BSN_50, BSL_50, BSN_51, BSL_51, BSN_52, BSL_52, BSN_53, BSL_53, BSN_54, BSL_54, BSN_55, BSL_55, BSN_56, BSL_56, BSN_57, BSL_57, BSN_58, BSL_58, BSN_59, BSL_59, BSN_60, BSL_60, BSN_61, BSL_61, BSN_62, BSL_62, BSN_63, BSL_63, BSN_64, BSL_64, BSN_65, BSL_65, BSN_66, BSL_66, BSN_67, BSL_67, BSN_68, BSL_68, BSN_69, BSL_69, BSN_70, BSL_70, BSN_71, BSL_71, BSN_72, BSL_72, BSN_73, BSL_73, BSN_74, BSL_74, BSN_75, BSL_75, BSN_76, BSL_76, BSN_77, BSL_77, BSN_78, BSL_78, BSN_79, BSL_79, BSN_80, BSL_80, BSN_81, BSL_81, BSN_82, BSL_82, BSN_83, BSL_83, BSN_84, BSL_84, BSN_85, BSL_85, BSN_86, BSL_86, BSN_87, BSL_87, BSN_88, BSL_88, BSN_89, BSL_89, BSN_90, BSL_90, BSN_91, BSL_91, BSN_92, BSL_92, BSN_93, BSL_93, BSN_94, BSL_94, BSN_95, BSL_95, BSN_96, BSL_96, BSN_97, BSL_97, BSN_98, BSL_98, BSN_99, BSL_99, BSN_100, BSL_100, BSN_101, BSL_101, BSN_102, BSL_102, BSN_103, BSL_103, BSN_104, BSL_104, BSN_105, BSL_105, BSN_106, BSL_106, BSN_107, BSL_107, BSN_108, BSL_108, BSN_109, BSL_109, BSN_110, BSL_110, BSN_111, BSL_111, BSN_112, BSL_112, BSN_113, BSL_113, BSN_114, BSL_114, BSN_115, BSL_115, BSN_116, BSL_116, BSN_117, BSL_117, BSN_118, BSL_118, BSN_119, BSL_119, BSN_120, BSL_120, BSN_121, BSL_121, BSN_122, BSL_122, BSN_123, BSL_123, BSN_124, BSL_124, BSN_125, BSL_125, BSN_126, BSL_126, BSN_127, BSL_127, BSN_128, BSL_128, BSN_129, BSL_129, BSN_130, BSL_130, BSN_131, BSL_131, BSN_132, BSL_132, BSN_133, BSL_133, BSN_134, BSL_134, BSN_135, BSL_135, BSN_136, BSL_136, BSN_137, BSL_137, BSN_138, BSL_138, BSN_139, BSL_139, BSN_140, BSL_140, BSN_141, BSL_141, BSN_142, BSL_142, BSN_143, BSL_143, BSN_144, BSL_144, BSN_145, BSL_145, BSN_146, BSL_146, BSN_147, BSL_147, BSN_148, BSL_148, BSN_149, BSL_149, BSN_150, BSL_150, BSN_151, BSL_151, BSN_152, BSL_152, BSN_153, BSL_153, BSN_154, BSL_154,BSN_155, BSL_155, BSN_156, BSL_156, BSN_157, BSL_157,BSN_158, BSL_158) VALUES  (%s, %s, %s, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL, NULL);"
    val = (route_no, origin, destination)
    cur.execute(sql, val)
    conn.commit()
